# %% [markdown]
# <a href="https://colab.research.google.com/github/Mysterio-maker/STUDY-OF-PANDAS-IN-PYTHON/blob/main/EXPERIMENT_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 9
#
# ## Title- Study of pandas
#
# ## Amey Waghmare
# ## 25070123009
# ## A1

# %%
# PANDA - USED FOR STRUCTURED DATA
          DATA CLEANING

# %%
import pandas as pd

s= pd.Series([7,8,10,18,45])
s
# Out:
# 0     7
# 1     8
# 2    10
# 3    18
# 4    45
# dtype: int64

# %%
# CREATE DATA FRAME

data={
    "Name":["A","B","C","D"],
    "Marks":[85,90,95,100]
}
df=pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     95
# 3    D    100

# %%
df.head()
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     95
# 3    D    100

# %%
df.tail()
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     95
# 3    D    100

# %%
# Find structure of DataFrame
df.shape
# Out:
# (4, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 8

# %%
# Display Column Names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
# Access individual column

df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Name, dtype: object

# %%
# Access specific row

df.loc[1]
# Out:
# Name      B
# Marks    90
# Name: 1, dtype: object

# %%
# Adding a column

df["Grade"]=["First Class","Distinction","Second Class","Fail"]
df
# Out:
#   Name  Marks         Grade
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     95  Second Class
# 3    D    100          Fail

# %%
# Update Data in data frame

df.loc[0,"Marks"]= 88
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     95
# 3    D    100

# %%
df.drop("Grade", axis=1, inplace=True)
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     95
# 3    D    100

# %%
# perfrom basic statistical operations

df["Marks"].mean()
# Out:
# np.float64(93.25)

# %%
df["Marks"].max()
# Out:
# 100

# %%
df["Marks"].min()
# Out:
# 88

# %%
# Apply Conditioning

df[df["Marks"] > 90]
# Out:
#   Name  Marks
# 2    C     95
# 3    D    100
